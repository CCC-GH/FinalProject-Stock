# %%
import pandas as pd
import pandas_datareader as pdr
import matplotlib.pyplot as plt
from matplotlib import rcParams
from sklearn import linear_model
data=pd.read_csv('GME-CombinedDF_2020-01-01_2021-03-06.csv')

# %%
data
# Out:
#            Date  Close     Volume  Predict  SM1  SM2  SM3  SM4
# 0    2020-01-02   6.31  4453600.0      NaN  NaN  NaN  NaN  NaN
# 1    2020-01-03   5.88  3543900.0      NaN  NaN  NaN  NaN  NaN
# 2    2020-01-06   5.85  3394800.0      NaN  NaN  NaN  NaN  NaN
# 3    2020-01-07   5.52  5228000.0      NaN  NaN  NaN  NaN  NaN
# 4    2020-01-08   5.72  5629400.0      NaN  NaN  NaN  NaN  NaN
# ..          ...    ...        ...      ...  ...  ...  ...  ...
# 301  2021-03-15    NaN        NaN      NaN  NaN  NaN  NaN  NaN
# 302  2021-03-16    NaN        NaN      NaN  NaN  NaN  NaN  NaN
# 303  2021-03-17    NaN        NaN      NaN  NaN  NaN  NaN  NaN
# 304  2021-03-18    NaN        NaN      NaN  NaN  NaN  NaN  NaN
# 305  2021-03-19    NaN        NaN      NaN  NaN  NaN  NaN  NaN
#
# [306 rows x 8 columns]

# %%
data.corr() #correlation coefficients
# Out:
#             Close    Volume  Predict  SM1  SM2  SM3  SM4
# Close    1.000000  0.559467      NaN  NaN  NaN  NaN  NaN
# Volume   0.559467  1.000000      NaN  NaN  NaN  NaN  NaN
# Predict       NaN       NaN      NaN  NaN  NaN  NaN  NaN
# SM1           NaN       NaN      NaN  NaN  NaN  NaN  NaN
# SM2           NaN       NaN      NaN  NaN  NaN  NaN  NaN
# SM3           NaN       NaN      NaN  NaN  NaN  NaN  NaN
# SM4           NaN       NaN      NaN  NaN  NaN  NaN  NaN

# %%
rcParams['figure.figsize']=10,6
data.plot(kind='scatter', x='Date', y='Close' )
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
rcParams['figure.figsize']=10,6
data.plot(kind='scatter', x='Date', y='Close' )
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
rcParams['figure.figsize']=10,6
plt.plot(data.Volume)
plt.grid(True, color ='k', linestyle =':')
plt.title('Date vs Volume')
plt.xlabel('Date')
plt.ylabel('Volume')
# Out:
# Text(0, 0.5, 'Volume')

# %%
rcParams['figure.figsize']=10,6
plt.plot(data.Close)
plt.grid(True, color ='k', linestyle =':')
plt.title('Date vs Close')
plt.xlabel('Date')
plt.ylabel('Close')
# Out:
# Text(0, 0.5, 'Close')
